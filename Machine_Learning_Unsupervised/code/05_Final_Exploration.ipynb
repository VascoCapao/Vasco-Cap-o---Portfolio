# %% [markdown]
# # Final Analysis

# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio

# %%
outliers = pd.read_csv('outliers.csv')
df_with_clusters = pd.read_csv('df_with_clusters').drop('Unnamed: 0', axis=1)

# %%
# Add cluster column to the outliers DataFrame
outliers['cluster_ward'] = 'outlier'

# %%
outliers
# Out:
#       customer_id      customer_name  customer_gender  customer_age  \
# 0           24099     Raymond Maicus                1            49
# 1           28426    David Sheffield                1            34
# 2           35858      Ethel Stevens                0            63
# 3           25940       Joseph Smith                1            62
# 4           14772       James Powers                1            67
# ...           ...                ...              ...           ...
# 2047         3372   Delia Washington                0            48
# 2048           71       Sylvia Giles                0            56
# 2049        13583     Andrew Tegeler                1            65
# 2050        25851      Kelly Johnson                0            82
# 2051        21939  Beatrice Mcdougal                0            84
#
#       kids_home  teens_home  number_complaints  distinct_stores_visited  \
# 0           0.0         0.0                1.0                      1.0
# ...

# %%
df_with_clusters
# Out:
#        customer_id    customer_name  customer_gender  customer_age  kids_home  \
# 0            39634      David Frink                1            60        1.0
# 1            23937    Evelyn Calico                0            55        0.0
# 2             2431      Ora Boggess                0            83        0.0
# 3            10090    Lonnie Hopson                1            23        0.0
# 4            24058       Maria Hunt                0            65        1.0
# ...            ...              ...              ...           ...        ...
# 39640        48487  Amelia Crawford                0            41        1.0
# 39641        24856     Silvia Ramos                0            32        1.0
# 39642        21373    Addie Coronel                0            30        0.0
# 39643        19527        Mary Ross                0            35        1.0
# 39644         5120    Milton Friend                1            67        2.0
#
# ...

# %%
final_solution = pd.concat([outliers, df_with_clusters]).set_index('customer_id')
final_solution = final_solution[['customer_name', 'customer_gender', 'cluster_ward', 'latitude', 'longitude']]

# %%
final_solution.head()
# Out:
#                customer_name  customer_gender cluster_ward   latitude  \
# customer_id
# 24099         Raymond Maicus                1      outlier  38.716818
# 28426        David Sheffield                1      outlier  38.736827
# 35858          Ethel Stevens                0      outlier  38.759973
# 25940           Joseph Smith                1      outlier  38.759800
# 14772           James Powers                1      outlier  38.748837
#
#              longitude
# customer_id
# 24099        -9.183665
# 28426        -9.150803
# 35858        -9.166223
# 25940        -9.166566
# 14772        -9.172141

# %%
# Set the default template to 'plotly_white'
pio.templates.default = "plotly_white"

# Create a scatter mapbox plot using customer_info_precleaned dataframe
# Latitude and longitude are used as coordinates for the map, customer_name is used for hover information, and degree is used for color differentiation
fig = px.scatter_mapbox(final_solution, lat='latitude', lon='longitude', zoom=10, hover_name='customer_name', color='cluster_ward')

# Set the mapbox style to 'open-street-map'
fig.update_layout(mapbox_style="open-street-map")

# Show the figure
fig.show()

# %% [markdown]
# In this map, it's evident that outside of Lisbon, the majority of customers fall into the outlier category. While further in-depth studies to analyze the specifics and characteristics of these outliers may not be conducted, their prevalence highlights potential areas of interest for future research and strategic analysis.

# %%
final_solution.to_csv('SOLUTION.csv')
